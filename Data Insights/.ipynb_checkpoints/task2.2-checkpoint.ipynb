# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta, date
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import warnings
import math as ma
import seaborn as sns
from scipy.stats import kurtosis
from scipy.stats import skew
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# read data to df
df = pd.read_csv('data_clean.csv')

# show df first 5 rows
df.head()
# Out:
#    customer_id      first_name  last_name  gender  3y_bike_purchases  \
# 0            1         Laraine  Medendorp  Female                 93
# 1            2             Eli    Bockman    Male                 81
# 2            3           Arlin     Dearle    Male                 61
# 3            4          Talbot        NaN    Male                 33
# 4            5  Sheila-kathryn     Calton  Female                 56
#
#           DOB               job_title job_industry_category  \
# 0  1953-10-12     Executive Secretary                Health
# 1  1980-12-16  Administrative Officer    Financial Services
# 2  1954-01-20      Recruiting Manager              Property
# 3  1961-10-03                     NaN                    IT
# 4  1977-05-13           Senior Editor                   NaN
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes    11.0   060 Morning Avenue
# ...

# %%
# Select rows with index value "A" and store in dataframe A
dfA = df.loc[df['customer_id'] <= 4000]

# Select rows with index value "B" and store in dataframe B
dfB = df.loc[df['customer_id'] >4000]

# %%
dfA
# Out:
#       customer_id      first_name  last_name       gender  3y_bike_purchases  \
# 0               1         Laraine  Medendorp       Female                 93
# 1               2             Eli    Bockman         Male                 81
# 2               3           Arlin     Dearle         Male                 61
# 3               4          Talbot        NaN         Male                 33
# 4               5  Sheila-kathryn     Calton       Female                 56
# ...           ...             ...        ...          ...                ...
# 3995         3996         Rosalia   Halgarth       Female                  8
# 3996         3997          Blanch     Nisuis       Female                 87
# 3997         3998          Sarene    Woolley  Unspecified                 60
# 3998         3999       Patrizius        NaN         Male                 11
# 3999         4000           Kippy    Oldland         Male                 76
#
# ...

# %%
dfB
# Out:
#       customer_id first_name  last_name  gender  3y_bike_purchases  \
# 4000         4001    Chickie    Brister    Male                 86
# 4001         4002      Morly     Genery    Male                 69
# 4002         4003    Ardelis  Forrester  Female                 10
# 4003         4004     Lucine      Stutt  Female                 64
# 4004         4005    Melinda     Hadlee  Female                 34
# ...           ...        ...        ...     ...                ...
# 4995         4996  Ferdinand  Romanetti    Male                 60
# 4996         4997       Burk    Wortley    Male                 22
# 4997         4998   Melloney      Temby  Female                 17
# 4998         4999     Dickie    Cubbini    Male                 30
# 4999         5000      Sylas    Duffill    Male                 56
#
#              DOB                     job_title job_industry_category  \
# 4000  1957-07-12               General Manager         Manufacturing
# ...

# %%
# read data to df
dfT = pd.read_excel('D:\Resume\KPMG\KPMG_VI_New_raw_data_update_final.xlsx', sheet_name = 'Transactions')

# show df first 5 rows
dfT.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
# Convert "flag" column to boolean using pd.to_numeric
dfT['online_order'] = dfT['online_order'].astype(bool)

# %%
dfT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             20000 non-null  bool
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
# Create count plot using Seaborn
sns.countplot(x='online_order', data=dfT)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %%
## Categorical Variables
sns.countplot(x='order_status',data=dfT)
# Out:
# <AxesSubplot:xlabel='order_status', ylabel='count'>

# %%
ax = sns.countplot(x='brand',data=dfT)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'Solex'),
#  Text(1, 0, 'Trek Bicycles'),
#  Text(2, 0, 'OHM Cycles'),
#  Text(3, 0, 'Norco Bicycles'),
#  Text(4, 0, 'Giant Bicycles'),
#  Text(5, 0, 'WeareA2B')]

# %%
sns.countplot(x='product_line',data=dfT)
# Out:
# <AxesSubplot:xlabel='product_line', ylabel='count'>

# %%
sns.countplot(x='product_class',data=dfT)
# Out:
# <AxesSubplot:xlabel='product_class', ylabel='count'>

# %%
sns.countplot(x='product_size',data=dfT)
# Out:
# <AxesSubplot:xlabel='product_size', ylabel='count'>

# %%
## Numerical Variables

sns.distplot(dfT['product_id'])
# Out:
# <AxesSubplot:xlabel='product_id', ylabel='Density'>

# %%
sns.distplot(dfT['list_price'])
# Out:
# <AxesSubplot:xlabel='list_price', ylabel='Density'>

# %%
sns.distplot(dfT['standard_cost'])
# Out:
# <AxesSubplot:xlabel='standard_cost', ylabel='Density'>

# %%
# Merge df1 and df2 on the "ID" column
merged_df = pd.merge(dfA, dfT, on='customer_id')
merged_df
# Out:
#        customer_id first_name  last_name  gender  3y_bike_purchases  \
# 0                1    Laraine  Medendorp  Female                 93
# 1                1    Laraine  Medendorp  Female                 93
# 2                1    Laraine  Medendorp  Female                 93
# 3                1    Laraine  Medendorp  Female                 93
# 4                1    Laraine  Medendorp  Female                 93
# ...            ...        ...        ...     ...                ...
# 19992         3500       Josy    Fleeman  Female                 71
# 19993         3500       Josy    Fleeman  Female                 71
# 19994         3500       Josy    Fleeman  Female                 71
# 19995         3500       Josy    Fleeman  Female                 71
# 19996         3500       Josy    Fleeman  Female                 71
#
#               DOB            job_title job_industry_category  \
# 0      1953-10-12  Executive Secretary                Health
# ...

# %%
num_unique_values = merged_df["customer_id"].nunique()
num_unique_values
# Out:
# 3493

# %%
merged_df.to_csv('merged_df.csv', encoding='utf-8', index=True)
